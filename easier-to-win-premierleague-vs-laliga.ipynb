# %% [markdown]
# # 🧮 **<span style="color: DarkGreen; font-family:Times New Roman;">Is it statistically easier to win the Premier League vs La Liga?</span>**
# ## 👹 **<span style="color: DarkGreen; font-family:Times New Roman;">numbers can sometimes be deceiving</span>**
#
# ---

# %% [markdown]
# <div style="width:100%;height:0;padding-bottom:56%;position:relative;"><iframe src="https://giphy.com/embed/26FLeS7kHPkYyaojS" width="100%" height="100%" style="position:absolute" frameBorder="0" class="giphy-embed" allowFullScreen></iframe></div><p><a href="https://giphy.com/gifs/lfc-arrans-liverpoolfc-26FLeS7kHPkYyaojS"></a></p>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            text-align:center;
#            border-radius:5px;
#            background-color:lightgreen;
#            letter-spacing:0.5px">
# <span style="padding: 10px;
#               color:white;font-size:310%;
#            font-family:Time News Roman; color: DarkGreen">
# 📋 Table of Contents
#     </span>
# </div>
#
#
#  ## **1. [Introduction](#introduction)**
# ## **2. [Body](#body)**
# > **2.1. [Install and Import important libraries, Read the data](#iaiil)**
#
# > **2.2. [Preprocessing](#preprocessing)**
#
# > **2.3. [Null Hypothesis](#nullhypothesis)**
#
# > **2.4. [Check Normality](#checknormality)**
#
# > **2.5. [T-Test](#ttest)**
#
# > **2.6. [Result](#result)**
#
#
# ## **3. [Conclusion](#conclusion)**

# %% [markdown]
# # 📖 **<span style="color: DarkGreen; font-family:Times New Roman;">INTRODUCTION</span>** <a name="introduction"></a>
# ---

# %% [markdown]
# The debate over which football league is more challenging, the Premier League or La Liga, has long intrigued fans and potential investors alike. In this article, we aim to settle the discussion using statistical analysis. By examining the average points earned by the league winners from 2009 to 2022, we'll compare the difficulty of clinching the top spot in each league. However, we won't solely rely on numbers; we'll employ a T-Test to ensure the statistical significance of our findings.
#
# The dataset used for this analysis is the "Performance Data on Football Teams 09 to 22." This dataset encompasses a comprehensive range of performance statistics for football teams participating in the Premier League and La Liga during the period from 2009 to 2022. It includes data on various aspects of team performance, such as points earned, goals scored, goal differentials, and other relevant metrics.

# %% [markdown]
# **[⬆️Back to Table of Contents ⬆️](#toc)**

# %% [markdown]
# # 🦴 **<span style="color: DarkGreen; font-family:Times New Roman;">BODY</span>**<a name="body"></a>
# ---

# %% [markdown]
# ## 🛠️ <span style="color: DarkGreen; font-family:Times New Roman;">Install and Import important libraries, Read the data</span> <a name="iaiil"></a>
# ---

# %%
import pandas as pd
import pingouin as pg

# %%
df = pd.read_csv("/kaggle/input/performance-data-on-football-teams-09-to-22/Complete Dataset 2.csv")

# %% [markdown]
# **[⬆️Back to Table of Contents ⬆️](#toc)**

# %% [markdown]
# ## ⚗️ <span style="color: DarkGreen; font-family:Times New Roman;">Preprocessing</span> <a name="preprocessing"></a>
# ---

# %%
df.head()
# Out:
#                               Key               Team          League  \
# 0            Chelsea DL 2009/2010            Chelsea  Premier League
# 1  Manchester United DL 2009/2010  Manchester United  Premier League
# 2          Tottenham DL 2009/2010          Tottenham  Premier League
# 3            Arsenal DL 2009/2010            Arsenal  Premier League
# 4        Aston Villa DL 2009/2010        Aston Villa  Premier League
#
#       Season  Rank  Games  Wins  Draws  Losses  Points  ...  Nutmegs  \
# 0  2009/2010   1.0   38.0  27.0    5.0     6.0    86.0  ...      NaN
# 1  2009/2010   2.0   38.0  27.0    4.0     7.0    85.0  ...      NaN
# 2  2009/2010   4.0   38.0  21.0    7.0    10.0    70.0  ...      NaN
# 3  2009/2010   3.0   38.0  23.0    6.0     9.0    75.0  ...      NaN
# 4  2009/2010   6.0   38.0  17.0   13.0     8.0    64.0  ...      NaN
#
#    Controlled  DistMovedWithBall  ProgressiveDistMoved  ProgC  \
# 0         NaN                NaN                   NaN    NaN
# ...

# %%
df.tail()
# Out:
#                                 Key              Team            League  \
# 1685  Shakhtar Donetsk CL 2021/2022  Shakhtar Donetsk  Champions League
# 1686          FC Porto CL 2021/2022          FC Porto  Champions League
# 1687       Dynamo Kyiv CL 2021/2022       Dynamo Kyiv  Champions League
# 1688          Besiktas CL 2021/2022          Besiktas  Champions League
# 1689         Malmoe FF CL 2021/2022         Malmoe FF  Champions League
#
#          Season  Rank  Games  Wins  Draws  Losses  Points  ...  Nutmegs  \
# 1685  2021/2022  32.0    NaN   NaN    NaN     NaN     NaN  ...      NaN
# 1686  2021/2022  32.0    NaN   NaN    NaN     NaN     NaN  ...      NaN
# 1687  2021/2022  32.0    NaN   NaN    NaN     NaN     NaN  ...      NaN
# 1688  2021/2022  32.0    NaN   NaN    NaN     NaN     NaN  ...      NaN
# 1689  2021/2022  32.0    NaN   NaN    NaN     NaN     NaN  ...      NaN
#
#       Controlled  DistMovedWithBall  ProgressiveDistMoved  ProgC  \
# ...

# %%
df.describe()
# Out:
#               Rank        Games         Wins        Draws       Losses  \
# count  1688.000000  1272.000000  1272.000000  1272.000000  1272.000000
# mean     13.212085    37.105346    13.860849     9.390723    13.853774
# std      11.652804     1.936824     5.839471     2.944652     5.338193
# min       1.000000    27.000000     2.000000     2.000000     0.000000
# 25%       6.000000    38.000000    10.000000     7.000000    10.000000
# 50%      12.000000    38.000000    12.000000     9.000000    14.000000
# 75%      17.000000    38.000000    17.000000    11.000000    18.000000
# max     323.000000    38.000000    33.000000    19.000000    29.000000
#
#             Points     GoalsFor  GoalsAgainst  GoalDifference        Goals  \
# count  1272.000000  1272.000000   1272.000000      1272.00000  1690.000000
# mean     50.938679    50.680818     50.660377         0.02044    40.983432
# std      16.656978    16.698945     12.701106        25.64368    22.574074
# ...

# %%
df.dtypes
# Out:
# Key                           object
# Team                          object
# League                        object
# Season                        object
# Rank                         float64
#                               ...
# ProgressiveIntoFinalThird    float64
# ProgressiveInto18Yard        float64
# Miscontrols                  float64
# MiscontrolsAfterTackle       float64
# ProgressivePassReceived      float64
# Length: 93, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1690 entries, 0 to 1689
# Data columns (total 93 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Key                           1690 non-null   object
#  1   Team                          1690 non-null   object
#  2   League                        1690 non-null   object
#  3   Season                        1690 non-null   object
#  4   Rank                          1688 non-null   float64
#  5   Games                         1272 non-null   float64
#  6   Wins                          1272 non-null   float64
#  7   Draws                         1272 non-null   float64
#  8   Losses                        1272 non-null   float64
#  9   Points                        1272 non-null   float64
#  10  GoalsFor                      1272 non-null   float64
#  11  GoalsAgainst                  1272 non-null   float64
# ...

# %%
# Add start and end of the Season
df["Start Season"] = df["Season"].apply(lambda x : int(x[:4]))
df["End Season"] = df["Season"].apply(lambda x : (x[5:]))

# %% [markdown]
# **[⬆️Back to Table of Contents ⬆️](#toc)**

# %% [markdown]
# ## 🇭<sub>0</sub> <span style="color: DarkGreen; font-family:Times New Roman;">Null hypothesis: Winning the Premier League is more challenging than winning La Liga </span><a name="nullhypothesis"></a>
# ---

# %%
# Select all Winners Premier League from 2009-2022
pl = df[(df["League"] == "Premier League") & (df["Rank"] == 1)][["League","Team","Start Season", "End Season","Points","Wins"]].reset_index(drop = True)

# %%
# Select all Winners La Liga from 2009-2022
ll = df[(df["League"] == "La Liga") & (df["Rank"] == 1)][["League","Team","Start Season", "End Season","Points","Wins"]].reset_index(drop = True)

# %% [markdown]
# To determine the level of difficulty in winning each league, we start by considering the main metric—points. The team with the most points is declared the winner. Calculating the average points earned by the winners of La Liga and the Premier League during the specified period, we obtain the following results:

# %%
print(f'''La Liga Winners Average Points (2009-2022): {round(ll["Points"].mean(),2)}''')
print(f'''Premier League Winners Average Points (2009-2022): {round(pl["Points"].mean(),2)}''')
# Out:
# La Liga Winners Average Points (2009-2022): 92.46
# Premier League Winners Average Points (2009-2022): 89.77

# %% [markdown]
# At first glance, it seems that La Liga winners, on average, accumulate a higher number of points compared to Premier League winners. This observation may lead to the assumption that winning La Liga is more challenging. However, numbers can sometimes be deceiving, necessitating a deeper analysis.

# %% [markdown]
# **[⬆️Back to Table of Contents ⬆️](#toc)**

# %% [markdown]
# ## 🔔 <span style="color: DarkGreen; font-family:Times New Roman;">Check normality</span><a name="checknormality"></a>
# ---

# %% [markdown]
# To make a fair and scientifically supported comparison, we employ the T-Test methodology. Before conducting the T-Test, we must verify the normality of the data for both leagues.

# %%
print(f'''Premier League Winner Points (2009-2022) normality -> {pg.normality(pl.Points.values)["normal"].values[0]}''')
print(f'''La Liga Winner Points (2009-2022) normality -> {pg.normality(ll.Points.values)["normal"].values[0]}''')
# Out:
# Premier League Winner Points (2009-2022) normality -> True
# La Liga Winner Points (2009-2022) normality -> True

# %% [markdown]
# **[⬆️Back to Table of Contents ⬆️](#toc)**

# %% [markdown]
# ## 🧪 <span style="color: DarkGreen; font-family:Times New Roman;">T-Test</span><a name="ttest"></a>

# %% [markdown]
# Having confirmed the normal distribution of both datasets, we proceed to conduct the T-Test. Our null hypothesis states that winning the Premier League is more challenging than winning La Liga.

# %%
pg.ttest(ll.Points.values, pl.Points.values, correction = False, alternative = 'greater')
# Out:
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test  1.170357   24     greater  0.126674  [-1.24, inf]  0.459052  1.198
#
#            power
# T-test  0.305916

# %% [markdown]
# **[⬆️Back to Table of Contents ⬆️](#toc)**

# %% [markdown]
# # ⚽ <span style="color: DarkGreen; font-family:Times New Roman;">Result</span><a name="result"></a>

# %% [markdown]
# The p-value obtained from the T-Test is greater than the conventional significance level of 5%. Therefore, we fail to reject the null hypothesis, suggesting that winning the Premier League is statistically harder than winning La Liga.

# %% [markdown]
# **[⬆️Back to Table of Contents ⬆️](#toc)**

# %% [markdown]
# # 📕 **<span style="color: DarkGreen; font-family:Times New Roman;">CONCLUSION</span>**  <a name="conclusion"></a>
# ---

# %% [markdown]
# This statistical and scientific analysis settles the debate regarding the relative difficulty of winning the Premier League versus La Liga. Despite the initial perception that La Liga winners accrue more average points, the T-Test results demonstrate that clinching the top spot in the Premier League is statistically more challenging. Whether you're a serious investor or an avid fan seeking an answer to this long-standing debate, these findings provide valuable insights for making informed decisions.

# %% [markdown]
# **[⬆️Back to Table of Contents ⬆️](#toc)**
